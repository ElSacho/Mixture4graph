# %%
# Out:
# Running cells with '/Users/alexandrefrancois/Documents/MVA/Probabilistic graphical models/Code projet/.conda/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/alexandrefrancois/Documents/MVA/Probabilistic graphical models/Code projet/.conda ipykernel --update-deps --force-reinstall'

# %%
import numpy as np
import matplotlib.pyplot as plt 
import networkx as nx
from Graph_Generator import GraphGenerator

# %%
G=GraphGenerator(4,np.array([[0,1,0,0],[1,0,1,0],[0,1,0,1],[0,0,1,0]]),[.4,.1,.1,.4])
G.show_graph(10)

# %%
G=GraphGenerator(2,np.array([[1,.3],[.3,1]]),[.5,.5])
G.show_graph(10)

# %%
GraphGenerator.test(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/alexandrefrancois/Documents/MVA/Probabilistic graphical models/Code projet/.conda/Graph_plot.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexandrefrancois/Documents/MVA/Probabilistic%20graphical%20models/Code%20projet/.conda/Graph_plot.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> GraphGenerator.test(G)
#
# AttributeError: type object 'GraphGenerator' has no attribute 'test'
