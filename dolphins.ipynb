# %%
from visualize_gml_data import gml_dataset 
import utils
from generator import generate, generate_and_give_tau
import em_gml
import initialisation_methods as init

# %%
dolphins=gml_dataset('data/dolphins/dolphins.gml')

# %%
gml_dataset.print_general(dolphins)
# Out:
# The graph has  62  nodes and  159  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  62 nodes
# The largest connected component in the graph has  159  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  12
# The mean degree of a node is :  5.129032258064516
# The median degree of a node is :  5.0
# The clustering coefficient of the graph G is :  0.3087757313109426

# %%
gml_dataset.plot_figure_graph(dolphins)

# %%
gml_dataset.show_graph(dolphins)

# %%
model=em_gml.mixtureModel(dolphins)
results=model.fit()
# Out:
# number of clusters 2
# /Users/alexandrefrancois/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/alexandrefrancois/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# number of clusters 3
# number of clusters 4
# /Users/alexandrefrancois/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
model.plot_icl()

# %%
utils.show_graph_cluster_color(dolphins.data, model.results[2]['tau'])

# %%
model.plot_adjency_matrix(2)

# %%
tau_modularity=init.modularity_clustering(dolphins.data,2)
tau_spectral=init.spectral_clustering(dolphins.data,2)
tau_hierarchical=init.hierarchical_clustering(dolphins.data, 2)
# Out:
# clusters [[2, 3, 52, 44, 39, 33, 28, 25, 21, 19, 17, 15, 13, 10, 9, 8, 7, 6, 4, 5, 53, 46, 41, 35, 36, 54, 47, 42, 37, 30, 27, 24, 20, 18, 16, 14, 11, 12, 55, 48, 49, 56, 50, 43, 38, 31, 32, 57, 51, 45, 40, 34, 29, 26, 22, 23, 58, 59, 60, 61], [0, 1]]
# /Users/alexandrefrancois/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
utils.plot_adjency_matrix(dolphins.data, tau_modularity, 2)
utils.plot_adjency_matrix(dolphins.data, tau_spectral, 2)
utils.plot_adjency_matrix(dolphins.data, tau_hierarchical, 2)

# %%
utils.show_graph_cluster_color(dolphins.data, model.results[2]['tau'])
