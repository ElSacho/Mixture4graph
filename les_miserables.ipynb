# %%
# Out:
# ...
#   Using cached GDAL-3.8.1.tar.gz (802 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [85 lines of output]
#       running egg_info
#       creating /private/var/folders/kk/m7r241y560174wvw5cvj2dfm0000gn/T/pip-pip-egg-info-9hb0bj_0/GDAL.egg-info
#       writing /private/var/folders/kk/m7r241y560174wvw5cvj2dfm0000gn/T/pip-pip-egg-info-9hb0bj_0/GDAL.egg-info/PKG-INFO
#       writing dependency_links to /private/var/folders/kk/m7r241y560174wvw5cvj2dfm0000gn/T/pip-pip-egg-info-9hb0bj_0/GDAL.egg-info/dependency_links.txt
#       writing requirements to /private/var/folders/kk/m7r241y560174wvw5cvj2dfm0000gn/T/pip-pip-egg-info-9hb0bj_0/GDAL.egg-info/requires.txt
#       writing top-level names to /private/var/folders/kk/m7r241y560174wvw5cvj2dfm0000gn/T/pip-pip-egg-info-9hb0bj_0/GDAL.egg-info/top_level.txt
# ...

# %%
from visualize_gml_data import gml_dataset 
import em
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/alexandrefrancois/Documents/MVA/Probabilistic graphical models/Code projet/Mixture4graph/les_miserables.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/alexandrefrancois/Documents/MVA/Probabilistic%20graphical%20models/Code%20projet/Mixture4graph/les_miserables.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from visualize_gml_data import gml_dataset
# ----> <a href='vscode-notebook-cell:/Users/alexandrefrancois/Documents/MVA/Probabilistic%20graphical%20models/Code%20projet/Mixture4graph/les_miserables.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import em
#
# File ~/Documents/MVA/Probabilistic graphical models/Code projet/Mixture4graph/em.py:5
#       2 import networkx as nx
#       3 import matplotlib.pyplot as plt
# ----> 5 from utils import plot_JRX, plot_ICL
#       7 from scipy.sparse.linalg import eigs
# ...

# %%
miserables=gml_dataset('data/lesmis/lesmis.gml')

# %%
gml_dataset.print_general(miserables)
# Out:
# The graph has  77  nodes and  254  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  77 nodes
# The largest connected component in the graph has  254  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  36
# The mean degree of a node is :  6.597402597402597
# The median degree of a node is :  6.0
# The clustering coefficient of the graph G is :  0.49893162393162394

# %%
gml_dataset.plot_figure_graph(miserables)
