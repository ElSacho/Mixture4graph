# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

import vizualize_data as vd

from EM_torch import mixtureModel

# %%
miserables = nx.read_gml("data/lesmis/lesmis.gml")

# %%
vd.plot_figure_graph(miserables)
vd.print_generalitize(miserables)
# Out:
# The graph has  77 nodes, and  254  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  77 nodes
# The largest connected component in the graph has  254  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  36
# The mean degree of a node is :  6.597402597402597
# The median degree of a node is :  6.0
# The clustering coefficient of the graph G is :  0.49893162393162394

# %%
model = mixtureModel(miserables)
model.fit(range(2,6))
# Out:
# Fit finished for  2  clusters
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %%
model.plot_icl()
model.plot_jrx()
model.plot_all_adjency_matrices(show_names = True)

# %%
names_index = [(index, name) for index, name in enumerate(miserables)]

# %%
print(names_index[0])
# Out:
# (0, 'Myriel')

# %%
import json
import networkx as nx

# Chemin vers votre fichier JSON
file_path = 'data/evelinag-star-wars-network/starwars-episode-7-mentions.json'

# Lire les données depuis le fichier JSON
with open(file_path, 'r') as file:
    data = json.load(file)

# Créer un graphique vide
star_wars = nx.Graph()

# Ajouter des nœuds au graphique
node_names = []  # Garder une trace de l'ordre des noms de nœuds
for node in data['nodes']:
    star_wars.add_node(node['name'], value=node['value'], colour=node['colour'])
    node_names.append(node['name'])

# Ajouter des arêtes au graphique
for edge in data['links']:
    source_name = node_names[edge['source']]
    target_name = node_names[edge['target']]
    star_wars.add_edge(source_name, target_name, weight=edge['value'])

# %%
star_wars_data = data_visualisation(star_wars)
star_wars_data.plot_figure_graph()
star_wars_data.print_generalitize()
# Out:
# The graph has  28 nodes, and  147  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  28 nodes
# The largest connected component in the graph has  147  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  20
# The mean degree of a node is :  10.5
# The median degree of a node is :  9.0
# The clustering coefficient of the graph G is :  0.6381936887921654

# %%
model = mixtureModel(star_wars.subgraph(max(nx.connected_components(star_wars), key=len)))
model.fit(range(2,6))
model.plot_icl()
model.plot_jrx()
# model.plot_all_adjency_matrices(show_names = True)
# Out:
# Fit finished for  2  clusters
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %%
model = mixtureModel(star_wars.subgraph(max(nx.connected_components(star_wars), key=len)), initilisation_method='random')
model.fit(range(3,6))
model.plot_icl()
model.plot_jrx()
# model.plot_all_adjency_matrices(show_names = True)
# Out:
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %%
from utils import show_graph
ligne_to_avoid = [7, 10, 13]
for i in range(1, 15):
    if not i in ligne_to_avoid:
        line1 = nx.read_gml(f"data/metro/ligne_per_line/metro_network_line_{i}.gml")
        pos = nx.get_node_attributes(line1, 'pos')
        nx.draw(line1, pos=pos, with_labels=False, node_size=20, node_color='skyblue', font_size=10, width = 1)
        # Affichez le graphe
        plt.show()

# %%
line1 = nx.read_gml("combined_metro_network.gml")
pos = nx.get_node_attributes(line1, 'pos')
nx.draw(line1, pos=pos, with_labels=False, node_size=20, node_color='skyblue', font_size=10, width = 1)
# Affichez le graphe
plt.show()

# %%
data_metro = data_visualisation(line1)
data_metro.plot_figure_graph()
data_metro.print_generalitize()
model = mixtureModel(line1, initilisation_method='spectral', max_iter_EM=13)
model.fit(range(2,4))
# Out:
# The graph has  232 nodes, and  264  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  232 nodes
# The largest connected component in the graph has  264  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  8
# The mean degree of a node is :  2.2758620689655173
# The median degree of a node is :  2.0
# The clustering coefficient of the graph G is :  0.01348314606741573
# Fit finished for  2  clusters
# Fit finished for  3  clusters

# %%
model.plot_icl()
model.plot_jrx()

# %%
model.plot_all_adjency_matrices(show_names=True)
