# %%
import numpy as np

from utils import show_graph
from generator import generate

# %%
n_vertices = 10
pi = np.array([[0.2,1,0.2,0.2],[1,0.2,1,0.2],[0.2,1,0.2,1],[0.2,0.2,1,0.2]])
priors = np.array([0.1, 0.4, 0.4, 0.1])

graph = generate(n_vertices, pi , priors)
show_graph(graph)
