# %% [markdown]
# # Graph Generation and EM on those Graphs

# %% [markdown]
# ### How it Works
#
# - **Generate Graphs** \\
# If you want to generate a graph, you need to provide the model with the prior \(\pi\), \(\alpha\), and the number of vertices you want.
# You can call the generator with the function `generate` that will return the generated graph, or `generate_and_give_tau` that will return a tuple with the generated graph, and a vector to explain to which clusters all nodes belong.
#
# - **Estimate Parameters**  \\
#     - To estimate the parameters of a graph, you first need to initialize a model. To do this, you can call the `mixtureModel` class. \\
#     - Then, you can fit the data with the model by calling the `fit` function. You need to specify the number of clusters you want for your fit, and you can also provide the model with a list of number of clusters. You may want to add an initialization method for the first values of \(\tau\), to test the model with several initialization methods.
#
# - **Plot the results** \\
#     All the functions to plot the results are in the mixtureModel class.
#     - `plotJRX` will plot the values of the $\mathcal{J}(R_{\mathcal(X)}) for all the clusters that has been studied
#     - `plotICL` will plot the values of the ICL which is the value that we use to find the good number of clusters
#     - `plot_adjency_matrix` will plot the adjency matrices of the final model. If you do not precise any value for the number of clusters, it will plot all the adjency matrix, or just one if you precise the one you want. You may also want to see the labels of the nodes in the adjency matrix, that you can do using using show_names = True
#
# - **Generate a new graph ** \\
#     - Finaly, you can generate a new graph with the values of the model. To access those values, you can use the dictionary of the mixtureModel, with the number of clusters you need. It will give you another dictionnary with the returned 'tau', 'pi', 'prior' .. values that you can use.
#     - You can finish ploting the orignal graph and the generated one. To do so, use the function show_colors_multiple_graph, were you give the two graphs, their respective tau values (to add the color on the clusters) and the titles that you want for your two graphs.

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import show_graph, show_multiple_graph, show_graph_cluster_color, show_colors_multiple_graph
from generator import generate, generate_and_give_tau

from EM_torch import mixtureModel, return_priors_pi_from_graph, calculated_empirical_clustering_coefficient

import networkx as nx
import vizualize_data as vd

# %% [markdown]
# ### Some easy examples - Get your hands on the module
#
# This first example is a simple graph with only two clusters. The model converged quickly to the solution with two clusters.
# The aim of the section is to get your hands on the model we are using, and visualize its results.
# The second one is even more easy. Even if the values $\pi$ are only zeros and ones, the model converges.
# Finaly, the third one is a star graph. This one may look more difficult, as we need to highlight the fact that there is no connections between the edges of the same clusters. The model converge in this situation too.

# %%
np.random.seed(2)
n_vertices = 50
pi = np.array([[1,0.1],[0.1,1]])
priors = np.array([0.2,0.8])
true_n_clusters = len(priors)
max_iter = 50

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph, initilisation_method='random')
tab_clusters = [2,3,4,5]
model.fit(tab_clusters)

model.plot_jrx()
model.plot_icl()
model.plot_adjency_matrix(true_n_clusters, show_names=True)

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# Fit finished for  2  clusters
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %%
np.random.seed(2)
n_vertices = 40
pi = np.array([[1,0],[0,1]])
priors = np.array([0.5,0.5])
true_n_clusters = len(priors)
max_iter = 50

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph, initilisation_method='random')
tab_clusters = [2,3,4,5]
model.fit(tab_clusters)

model.plot_jrx()
model.plot_icl()
model.plot_adjency_matrix(true_n_clusters)

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# Fit finished for  2  clusters
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %%
np.random.seed(1)
n_vertices = 10
pi = np.array([[0,1],[1,0]])
priors = np.array([0.1,0.9])
true_n_clusters = len(priors)
max_iter = 50

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph, initilisation_method='random')
tab_clusters = [2,3,4,5]
model.fit(tab_clusters)

model.plot_jrx()
model.plot_icl()
model.plot_adjency_matrix(true_n_clusters)

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# Fit finished for  2  clusters
# Fit finished for  3  clusters
# Fit finished for  4  clusters
# Fit finished for  5  clusters

# %% [markdown]
# ### Impact of the initialisation
#
# Now we want to visualize the impact of the initialization method on the convergence of the EM algorithm.
# To do so, we generate a graph with 100 nodes and several configurations of the underlying structure $\pi$.
# We use another function `precise_fit` that will iterate the fit function for nbr_iter_per_cluster time per cluster, in order to reduce and show the variance of the different methods.
#
# You can give this function a list of method that you want to use, the string argument must be 'modularity', 'spectral','random', ou 'hierarchical'. In our experiments, we only studied the first three of them as the results from 'hierarchical' were not really interesting.

# %% [markdown]
# #### A first graph with many edges and diagonal coefficients close to 1

# %%
n_vertices = 100

pi = np.array([[1    , 0.2, 0.4, 0.1],
               [0.2  , 1  , 1  , 0.1],
               [0.4  , 1  , 1  ,   1],
               [0.1  , 0.1, 1  ,   1]])

priors = np.array([0.1, 0.4, 0.1, 0.4])
true_n_clusters = len(priors)
max_iter = 7

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph)
tab_clusters = [2,3,4,5,6]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=20 , max_iter_em=max_iter, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()

model.plot_jrx()
model.plot_adjency_matrix(true_n_clusters)

np.set_printoptions(precision=3)
priors, pi  = return_priors_pi_from_graph(graph, tau)
print('The true priors is :\n',priors)
print('And the estimated one is :\n',model.results[true_n_clusters]['priors'])

print('The true pi is :\n',pi)
print('And the estimated one is :\n',model.results[true_n_clusters]['pi'])

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# The true priors is :
#  [0.08 0.4  0.16 0.36]
# And the estimated one is :
#  [0.16 0.4  0.08 0.36]
# The true pi is :
#  [[0.875 0.209 0.406 0.128]
#  [0.209 0.975 1.    0.094]
#  [0.406 1.    0.938 1.   ]
#  [0.128 0.094 1.    0.972]]
# And the estimated one is :
#  [[0.938 1.    0.406 1.   ]
#  [1.    0.975 0.209 0.094]
#  [0.406 0.209 0.875 0.128]
#  [1.    0.094 0.128 0.972]]

# %% [markdown]
# #### A second graph with less edges and diagonal coefficients close to 1

# %%
n_vertices = 100

pi = np.array([[1    , 0.2, 0.4 , 0.1],
               [0.2  , 1  , 0.3 , 0.1],
               [0.4  , 0.3  , 1 , 0.7],
               [0.1  , 0.1, 0.7 ,   1]])

priors = np.array([0.1, 0.4, 0.1, 0.4])
true_n_clusters = len(priors)
max_iter = 7

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph)
tab_clusters = [2,3,4,5,6]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=20 , max_iter_em=max_iter, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()

model.fit(tab_n_clusters=[true_n_clusters], max_iter=max_iter, initilisation_method='spectral')
model.plot_jrx()
model.plot_adjency_matrix(true_n_clusters)

np.set_printoptions(precision=3)
priors, pi  = return_priors_pi_from_graph(graph, tau)
print('The true priors is :\n',priors)
print('And the estimated one is :\n',model.results[true_n_clusters]['priors'])

print('The true pi is :\n',pi)
print('And the estimated one is :\n',model.results[true_n_clusters]['pi'])

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# Fit finished for  4  clusters
# The true priors is :
#  [0.09 0.45 0.14 0.32]
# And the estimated one is :
#  [0.14 0.09 0.45 0.32]
# The true pi is :
#  [[0.889 0.193 0.413 0.09 ]
#  [0.193 0.978 0.286 0.096]
#  [0.413 0.286 0.929 0.683]
#  [0.09  0.096 0.683 0.969]]
# And the estimated one is :
#  [[0.929 0.413 0.286 0.683]
#  [0.413 0.889 0.193 0.09 ]
#  [0.286 0.193 0.978 0.096]
#  [0.683 0.09  0.096 0.969]]

# %% [markdown]
# #### A third graph where two nodes in the same classes are not likely to be connected

# %%
n_vertices = 100

pi = np.array([[0.1  , 0.2, 0.4, 0.1],
               [0.2  , 0.3, 1  , 0.1],
               [0.4  , 1  , 0.4,   1],
               [0.1  , 0.1, 1  ,0.9 ]])

priors = np.array([0.1, 0.4, 0.1, 0.4])
true_n_clusters = len(priors)
max_iter = 7

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph)
tab_clusters = [2,3,4,5,6]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=20 , max_iter_em=max_iter, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()

model.plot_jrx()
model.plot_adjency_matrix(true_n_clusters)

np.set_printoptions(precision=3)
priors, pi  = return_priors_pi_from_graph(graph, tau)
print('The true priors is :\n',priors)
print('And the estimated one is :\n',model.results[true_n_clusters]['priors'])

print('The true pi is :\n',pi)
print('And the estimated one is :\n',model.results[true_n_clusters]['pi'])

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# The true priors is :
#  [0.1  0.36 0.14 0.4 ]
# And the estimated one is :
#  [0.14 0.1  0.36 0.4 ]
# The true pi is :
#  [[0.12  0.233 0.379 0.117]
#  [0.233 0.273 1.    0.106]
#  [0.379 1.    0.378 1.   ]
#  [0.117 0.106 1.    0.868]]
# And the estimated one is :
#  [[0.378 0.38  1.    1.   ]
#  [0.38  0.12  0.234 0.117]
#  [1.    0.234 0.273 0.106]
#  [1.    0.117 0.106 0.868]]

# %%
n_vertices = 100
np.random.seed(2)

pi = np.array([[0.1  , 0.2, 0.4  , 0.1],
               [0.2  , 0.3, 0.9  , 0.1],
               [0.4  , 0.9, 0.4  , 0.9],
               [0.1  , 0.1, 0.9  , 0.9]])

priors = np.array([0.1, 0.4, 0.1, 0.4])
true_n_clusters = len(priors)
max_iter = 7

graph, tau = generate_and_give_tau(n_vertices, pi , priors)

model = mixtureModel(graph)
tab_clusters = [2,3,4,5,6]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=20 , max_iter_em=max_iter, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()

model.plot_jrx()
model.plot_adjency_matrix(true_n_clusters)

np.set_printoptions(precision=3)
priors, pi  = return_priors_pi_from_graph(graph, tau)
print('The true priors is :\n',priors)
print('And the estimated one is :\n',model.results[true_n_clusters]['priors'])

print('The true pi is :\n',pi)
print('And the estimated one is :\n',model.results[true_n_clusters]['pi'])

new_graph, new_tau = generate_and_give_tau(n_vertices, model.results[true_n_clusters]['pi'] , model.results[true_n_clusters]['priors'])
show_colors_multiple_graph([graph, new_graph],[tau, new_tau], ['Original graph with approximated tau', 'Graph generated after the EM'])
# Out:
# The true priors is :
#  [0.11 0.45 0.15 0.29]
# And the estimated one is :
#  [0.29  0.262 0.298 0.15 ]
# The true pi is :
#  [[0.132 0.19  0.382 0.088]
#  [0.19  0.312 0.905 0.088]
#  [0.382 0.905 0.444 0.929]
#  [0.088 0.088 0.929 0.851]]
# And the estimated one is :
#  [[0.851 0.073 0.101 0.929]
#  [0.073 0.224 0.256 0.649]
#  [0.101 0.256 0.319 0.937]
#  [0.929 0.649 0.937 0.444]]

# %% [markdown]
# ### Application to real graphs
#
# In this final part, we study the analysis of the graph on real world data.
# The first study is on the graph representing the coappearance network of characters in the novel Les Miserables of Victor Hugo.
#
# The second one presented in our report the 117th United States Congress House of Representatives was to heavy to be conducted on our CPU computer. We used the file `ssh_impact_of_the_initialisation.py` to produce the results that can be seen in the folder `results/twitter`, executing our code on an SSH connection, and leveraging the GPU compatibility of our code.
#
# Finally, we show one last result which is the output of the model on a graph representing the Paris Metro network. This particular graph is an example of one graph that be believe not to follow the structure of the ERMG model.

# %%
miserables_graph = nx.read_gml("data/lesmis/lesmis.gml")

vd.plot_figure_graph(miserables_graph)
vd.print_generalitize(miserables_graph)

show_graph(miserables_graph)
# Out:
# The graph has  77 nodes, and  254  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  77 nodes
# The largest connected component in the graph has  254  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  36
# The mean degree of a node is :  6.597402597402597
# The median degree of a node is :  6.0
# The clustering coefficient of the graph G is :  0.49893162393162394

# %%
model = mixtureModel(miserables_graph)
tab_clusters = [2,3,4,5,6,7,8,9]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=20 , max_iter_em=max_iter, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()

# %%
best_n_clusters = 5
best_initialisation_method = 'spectral'
model = mixtureModel(miserables_graph)
model.fit([best_n_clusters], initilisation_method= best_initialisation_method, max_iter=50)
model.plot_adjency_matrix(best_n_clusters, show_names=True)
# Out:
# Fit finished for  5  clusters

# %% [markdown]
# The clustering coefficient of the original graph is close to the one we can derive from the ERMG model (see the appendix of our report)

# %%
clust_EM = calculated_empirical_clustering_coefficient(model.results[best_n_clusters]['priors'], model.results[best_n_clusters]['pi'])
print('The clustering coefficient dirived from the formula of the ERMG is ',clust_EM, ' \nthat is close to the true one of the real graph, that is ',nx.transitivity(miserables_graph))
# Out:
# The clustering coefficient dirived from the formula of the ERMG is  0.46803963877402815
# that is close to the true one of the real graph, that is  0.49893162393162394

# %% [markdown]
# We now show that the Paris Metro's graph is not likelly to follow the ERMG model

# %%
metro_graph = nx.read_gml("data/metro/final_metro_network.gml")
pos = nx.get_node_attributes(metro_graph, 'pos')
nx.draw(metro_graph, pos=pos, with_labels=False, node_size=20, node_color='skyblue', font_size=10, width = 1)
plt.show()
vd.print_generalitize(metro_graph)
vd.plot_figure_graph(metro_graph)
# Out:
# The graph has  232 nodes, and  264  edges
# The graph has  1  connected components.
# The largest connected component in the graph has  232 nodes
# The largest connected component in the graph has  264  edges
# The minimum degree of a node is :  1
# The maximum degree of a node is :  8
# The mean degree of a node is :  2.2758620689655173
# The median degree of a node is :  2.0
# The clustering coefficient of the graph G is :  0.01348314606741573

# %%
model = mixtureModel(metro_graph)
tab_clusters = [2,3,4]

model.precise_fit(tab_clusters, nbr_iter_per_cluster=10 , max_iter_em=7, list_initialisation_methods = [ 'modularity', 'spectral','random'])
model.plot_repeated_ICL()
model.plot_jrx()

# %%
model.plot_adjency_matrix(2)
